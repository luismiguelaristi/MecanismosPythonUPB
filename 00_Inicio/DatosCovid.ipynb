# %% [markdown]
# # Datos Covid Antioquia
#
# https://www.datos.gov.co/Salud-y-Protecci-n-Social/Casos-positivos-de-Covid-19-en-el-departamento-de-/w3du-c2j6
#
# El dataset de toda colombia pesa 1 GB aproximadamente (https://www.datos.gov.co/Salud-y-Protecci-n-Social/Casos-positivos-de-COVID-19-en-Colombia-/gt2j-8ykr), por lo cual se usa el de antioquia.
#
# El objetivo de este cuaderno es reducir el tamaño de los datos para antioquia.

# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\LMAG\Downloads\Casos_positivos_de_Covid-19_en_el_departamento_de_Antioquia.csv")
# Out:
# C:\Users\LMAG\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (14) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#           fecha reporte web  ID de caso Fecha de notificación  \
# 0       2020-11-08 00:00:00     1137429   2020-11-05 00:00:00
# 1       2020-11-08 00:00:00     1137433   2020-11-04 00:00:00
# 2       2020-11-08 00:00:00     1137437   2020-11-03 00:00:00
# 3       2020-11-08 00:00:00     1137446   2020-11-05 00:00:00
# 4       2020-08-05 00:00:00      338105   2020-08-01 00:00:00
# ...                     ...         ...                   ...
# 954414  2021-09-10 00:00:00     4926139   2021-09-07 00:00:00
# 954415  2021-09-10 00:00:00     4926140   2021-09-07 00:00:00
# 954416  2021-09-10 00:00:00     4926143   2021-09-08 00:00:00
# 954417  2022-01-18 00:00:00     5580585   2022-01-14 00:00:00
# ...

# %%
df_redux = df.drop(["Fecha de recuperación","Tipo de contagio","Ubicación del caso","fecha reporte web","Fecha de notificación","Nombre del grupo étnico","Código ISO del país","Código DIVIPOLA departamento","Código DIVIPOLA municipio","Nombre departamento","Pertenencia étnica","Tipo de recuperación"],axis=1)
df_redux = df_redux.set_index("ID de caso")

# %%
df_redux
# Out:
#            Nombre municipio  Edad  Unidad de medida de edad Sexo Estado  \
# ID de caso
# 1137429            ENVIGADO    37                         1    F   Leve
# 1137433            ENVIGADO    37                         1    F   Leve
# 1137437              ITAGUI    36                         1    F   Leve
# 1137446            ENVIGADO    63                         1    F   Leve
# 338105             MEDELLIN    52                         1    M   Leve
# ...                     ...   ...                       ...  ...    ...
# 4926139           CHIGORODO    40                         1    M   Leve
# 4926140          DON MATIAS    40                         1    M   Leve
# 4926143            FREDONIA    51                         1    M   Leve
# 5580585            RIONEGRO    43                         1    M   Leve
# 5234027            MEDELLIN    22                         1    F   Leve
#
#            Nombre del país  Recuperado Fecha de inicio de síntomas  \
# ID de caso
# ...

# %%
df_redux.to_csv('COVID_Antioquia.csv')
